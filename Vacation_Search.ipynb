# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("WeatherPy_challenge.csv")
city_data_df.head(10)
# Out:
#    City_ID         City Country                 Date    Lat     Lng  Max Temp  \
# 0        0     La Ronge      CA  2020-01-05 19:25:58  55.10 -105.30      3.20
# 1        1       Baihar      IN  2020-01-05 19:25:58  22.11   80.55     52.38
# 2        2     Tumannyy      IN  2020-01-05 19:25:58  22.11   80.55     52.38
# 3        3    Neyshabur      IR  2020-01-05 19:25:59  36.21   58.79     35.44
# 4        4  East London      ZA  2020-01-05 19:25:59 -33.02   27.91     68.00
# 5        5     Saleaula      ZA  2020-01-05 19:25:59 -33.02   27.91     68.00
# 6        6     Portland      US  2020-01-05 19:25:59  43.66  -70.25     34.00
# 7        7   Kaitangata      NZ  2020-01-05 19:25:59 -46.28  169.85     50.00
# 8        8       Avarua      CK  2020-01-05 19:26:00 -21.21 -159.78     80.60
# 9        9       Atuona      PF  2020-01-05 19:26:00  -9.80 -139.03     80.49
#
#    Humidity  Cloudiness  Wind Speed Weather Description  \
# ...

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)
g_key
# Out:
# 'AIzaSyAH87X-PI8RQfWzT8amGlKi6P3N3ONdliM'

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip?"))
max_temp = float(input("What is the maximum temperature you would like for your trip?"))
raining = float(input("Do you want it to be raining? (0=no/1=yes)  "))
snowing = float(input("Do you want it to be snowing? (0=no/1=yes)  "))
# Out:
# What is the minimum temperature you would like for your trip?70
# What is the maximum temperature you would like for your trip?95
# Do you want it to be raining? (0=no/1=yes)  0
# Do you want it to be snowing? (0=no/1=yes)  0

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp) & \
                                       (city_data_df["Rain inches (last 3 hrs)"] >= raining) & \
                                       (city_data_df["Snow inches (last 3 hrs)"] == snowing)]
preferred_cities_df.head(100)
# Out:
#      City_ID          City Country                 Date    Lat     Lng  \
# 8          8        Avarua      CK  2020-01-05 19:26:00 -21.21 -159.78
# 9          9        Atuona      PF  2020-01-05 19:26:00  -9.80 -139.03
# 10        10       Rikitea      PF  2020-01-05 19:26:00 -23.12 -134.97
# 12        12  Ponta Do Sol      BR  2020-01-05 19:26:00 -20.63  -46.00
# 15        15          Naze      NG  2020-01-05 19:26:01   5.43    7.07
# ..       ...           ...     ...                  ...    ...     ...
# 270      270      Celestun      MX  2020-01-05 19:26:49  20.87  -90.40
# 274      274        Maputo      MZ  2020-01-05 19:23:33 -25.97   32.57
# 276      276         Nazca      PE  2020-01-05 19:26:50 -14.83  -74.94
# 277      277        Sorvag      PE  2020-01-05 19:26:50 -14.83  -74.94
# 280      280      Nokaneng      BW  2020-01-05 19:26:51 -19.66   22.19
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Weather Description  \
# ...

# %%
preferred_cities_df.count()
# Out:
# City_ID                     238
# City                        238
# Country                     237
# Date                        238
# Lat                         238
# Lng                         238
# Max Temp                    238
# Humidity                    238
# Cloudiness                  238
# Wind Speed                  238
# Weather Description         238
# Rain inches (last 3 hrs)    238
# Snow inches (last 3 hrs)    238
# dtype: int64

# %%
# Create DataFrame called WeatherPy_vacation to store hotel names along with city, country, max temp, and coordinates.
WeatherPy_vacation_df = preferred_cities_df[["City", "Country","Max Temp", "Weather Description" , "Lat", "Lng"]].copy()
WeatherPy_vacation_df["Hotel Name"] = ""
WeatherPy_vacation_df.head(10)
# Out:
#             City Country  Max Temp Weather Description    Lat     Lng  \
# 8         Avarua      CK     80.60          light rain -21.21 -159.78
# 9         Atuona      PF     80.49           clear sky  -9.80 -139.03
# 10       Rikitea      PF     76.03           clear sky -23.12 -134.97
# 12  Ponta Do Sol      BR     81.46          light rain -20.63  -46.00
# 15          Naze      NG     86.00                dust   5.43    7.07
# 16         Kapaa      US     77.00    scattered clouds  22.08 -159.32
# 17  Puerto Ayora      EC     84.20    scattered clouds  -0.74  -90.35
# 20     Road Town      VG     82.40    scattered clouds  18.42  -64.62
# 21        Yarada      IN     75.20                mist  17.65   83.27
# 22     Kavaratti      IN     80.87           clear sky  10.57   72.64
#
#    Hotel Name
# 8
# 9
# 10
# 12
# 15
# 16
# 17
# 20
# 21
# 22

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Set parameters to search for a hotel.
params = {"radius": 5000,"type": "lodging","key": g_key}

# %%
# Iterate through the DataFrame.
for index, row in WeatherPy_vacation_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

# Add the latitude and longitude to the params dictionary as values to
#   the location key.
    params["location"] = f"{lat},{lng}"

# Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
# Grab the first hotel from the results and store the name.
    try:
        WeatherPy_vacation_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
WeatherPy_vacation_df.head(15)
# Out:
#             City Country  Max Temp Weather Description    Lat     Lng  \
# 8         Avarua      CK     80.60          light rain -21.21 -159.78
# 9         Atuona      PF     80.49           clear sky  -9.80 -139.03
# 10       Rikitea      PF     76.03           clear sky -23.12 -134.97
# 12  Ponta Do Sol      BR     81.46          light rain -20.63  -46.00
# 15          Naze      NG     86.00                dust   5.43    7.07
# 16         Kapaa      US     77.00    scattered clouds  22.08 -159.32
# 17  Puerto Ayora      EC     84.20    scattered clouds  -0.74  -90.35
# 20     Road Town      VG     82.40    scattered clouds  18.42  -64.62
# 21        Yarada      IN     75.20                mist  17.65   83.27
# 22     Kavaratti      IN     80.87           clear sky  10.57   72.64
# 25        Barrow      AR     80.47          light rain -38.31  -60.23
# 26       Padilla      CO     89.60       broken clouds   3.23  -76.31
# ...

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Weather Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in WeatherPy_vacation_df.iterrows()]

# %%
# Add a pop-up marker for each city.
locations = WeatherPy_vacation_df[["Lat", "Lng"]]
weather_description = WeatherPy_vacation_df["Weather Description"]
max_temp = WeatherPy_vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
